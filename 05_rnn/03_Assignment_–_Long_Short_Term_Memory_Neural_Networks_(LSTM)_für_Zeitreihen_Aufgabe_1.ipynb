# %% [markdown]
# <a href="https://colab.research.google.com/github/dennisddschulz/cas-artificial-intelligence/blob/main/05_rnn/03_Assignment_%E2%80%93_Long_Short_Term_Memory_Neural_Networks_(LSTM)_f%C3%BCr_Zeitreihen_Aufgabe_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment – Long Short-Term Memory Neural Networks (LSTM) für Zeitreihen
#
#
#
# Bern University of Applied Sciences – CAS AI HS 25
# Dozent: Ilja Rasin
#
# Dieses Notebook gehört zur dritten Vorlesung (RNN).
#
# **Ziele dieser Einheit**
#
# - Grundidee von RNN / LSTM im Kontext von Zeitreihen verstehen
# - Eine synthetische Zeitreihe (Sinus + Rauschen) vorhersagen
# - Ein einfaches LSTM-Modell in PyTorch implementieren
# - Train/Validation/Test-Split und Fensterbildung für Time Series anwenden
# - Optional: Eigene Zeitreihe laden (z.B. S&P500 mit `yfinance`) und ausprobieren
#
# **Hinweis für Studierende (Assignment-Charakter)**
#
# - Lest das Notebook von oben nach unten.
# - Führt alle Zellen aus und versucht, jeden Schritt zu verstehen.
# - Die Aufgabenabschnitte (*Aufgaben*) enthalten konkrete Experimente, die ihr selbst durchführen sollt.

# %%
# 1. Imports und Basiskonfiguration

import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt

# Matplotlib Standard-Einstellungen (keine speziellen Farben)
plt.rcParams["figure.figsize"] = (10, 4)

# Reproduzierbarkeit: Zufalls-Saat setzen
torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## 2. Synthetische Zeitreihe: Sinus + Rauschen
#
# Wir beginnen mit einer **einfachen künstlichen Zeitreihe**, an der sich das Verhalten eines RNN gut demonstrieren lässt:
#
# $
# x_t = \sin(\omega t) + \epsilon_t
# $
#
# mit etwas Rauschen ($\epsilon_t\$).
#
# Später können wir **eigene Zeitreihen** (z.B. S&P500) an derselben Pipeline ausprobieren.

# %%
# 2.1 Zeitachse und Sinus-Zeitreihe erzeugen

n_points = 1000          # Anzahl der Zeitpunkte
t_max = 50               # "Zeit" (x-Achse) bis wohin wir gehen
t = np.linspace(0, t_max, n_points)

# Sauberer Sinus
signal_clean = np.sin(2 * math.pi * t / 10.0)  # Periode ~10

# Rauschen hinzufügen
noise = 0.3 * np.random.randn(n_points)
signal_noisy = signal_clean + noise

# In Torch-Tensor umwandeln
series = torch.tensor(signal_noisy, dtype=torch.float32)
series.shape
# Out:
# torch.Size([1000])

# %%
# 2.2 Visualisierung der Zeitreihe

plt.plot(t, series.numpy())
plt.title("Synthetische Zeitreihe (Sinus + Rauschen)")
plt.xlabel("Zeit")
plt.ylabel("Wert")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Fensterbildung (Sequences) für RNN
#
# Ein RNN erwartet **Sequenzen** als Input, z.B.:
#
# - Eingabe:  $x\_{t-29}, ..., x\_{t}$   (Fensterlänge = 30)
# - Ziel:     $x\_{t+1}$                (1-Schritt-Vorhersage)
#
# Wir definieren eine Funktion, die aus einem 1D-Tensor (Zeitreihe)
# Input-Sequenzen und Zielwerte erzeugt.
#
# Später können wir dieselbe Funktion auch für echte Zeitreihen verwenden.

# %%
# 3.1 Hilfsfunktion: aus 1D-Serie Fenster (Input, Target) erzeugen

def create_sequences(series: torch.Tensor, window_size: int, horizon: int = 1):
    """
    Erzeugt Eingabe-/Ziel-Paare aus einer 1D-Zeitreihe.

    series:      1D Tensor der Länge N
    window_size: Anzahl der Vergangenheitswerte pro Input-Sequenz
    horizon:     wie viele Schritte in die Zukunft vorhergesagt werden (hier: 1)

    Rückgabe:
        X: Tensor der Form (num_samples, window_size)
        y: Tensor der Form (num_samples, horizon)
    """
    xs = []
    ys = []

    N = len(series)
    # Letzter Index, bei dem noch ein vollständiges Fenster + Horizon möglich ist
    last_idx = N - window_size - horizon + 1

    for start in range(last_idx):
        end = start + window_size
        target_start = end
        target_end = end + horizon

        x_window = series[start:end]
        y_window = series[target_start:target_end]

        xs.append(x_window)
        ys.append(y_window)

    X = torch.stack(xs)  # (num_samples, window_size)
    y = torch.stack(ys)  # (num_samples, horizon)

    return X, y


window_size = 30     # Länge des historischen Fensters
horizon = 1          # 1-Schritt-Vorhersage

X_all, y_all = create_sequences(series, window_size, horizon)
X_all.shape, y_all.shape
# Out:
# (torch.Size([970, 30]), torch.Size([970, 1]))

# %% [markdown]
# ## 4. Train/Validation/Test-Split
#
# Wir teilen die generierten Fenster in drei Teile:
#
# - **Train**: für das Lernen der Gewichte
# - **Validation**: zur Hyperparameter-Abstimmung
# - **Test**: zur finalen Evaluation
#
# Wir verwenden einen einfachen Split nach Zeit (kein Mischen, um Leckage zu vermeiden).

# %%
# 4.1 Zeitlicher Split der Sequenzen

num_samples = X_all.shape[0]

train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

train_end = int(num_samples * train_ratio)
val_end = train_end + int(num_samples * val_ratio)

X_train = X_all[:train_end]
y_train = y_all[:train_end]

X_val = X_all[train_end:val_end]
y_val = y_all[train_end:val_end]

X_test = X_all[val_end:]
y_test = y_all[val_end:]

X_train.shape, X_val.shape, X_test.shape
# Out:
# (torch.Size([679, 30]), torch.Size([145, 30]), torch.Size([146, 30]))

# %%
# 4.2 Dataset- und DataLoader-Klassen

class TimeSeriesDataset(Dataset):
    """
    Einfache Dataset-Klasse für Zeitreihenfenster.
    """

    def __init__(self, X: torch.Tensor, y: torch.Tensor):
        # X: (num_samples, window_size)
        # y: (num_samples, horizon)
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x_seq = self.X[idx]  # (window_size,)
        y_val = self.y[idx]  # (horizon,)

        # RNN/LSTM erwartet Input der Form (batch, seq_len, input_size)
        # Hier: input_size = 1, also wir erweitern die letzte Dimension
        x_seq = x_seq.unsqueeze(-1)  # (window_size, 1)

        return x_seq, y_val


batch_size = 32

train_dataset = TimeSeriesDataset(X_train, y_train)
val_dataset = TimeSeriesDataset(X_val, y_val)
test_dataset = TimeSeriesDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## 5. LSTM-Modell definieren
#
# Wir verwenden ein einfaches LSTM (statt plain RNN), weil es in der Praxis
# bei längeren Sequenzen stabiler ist.
#
# **Eingabeform**:
# - Batch:   \(B\)
# - Zeit:    \(T\) (Fensterlänge)
# - Feature: \(F = 1\) (ein Skalar pro Zeitschritt)
#
# LSTM-Ausgabe:
# - Wir nehmen den **letzten Zeitschritt** der Hidden States und leiten ihn
#   über ein Fully-Connected-Layer auf die gewünschte Horizon-Dimension (hier: 1) ab.

# %%
# 5.1 LSTM-Modellklasse

class LSTMForecaster(nn.Module):
    def __init__(self, input_size: int = 1, hidden_size: int = 32, num_layers: int = 1, output_size: int = 1):
        """
        Einfacher LSTM-basierter Forecaster.

        input_size:  Dimension der Eingabefeatures (hier 1)
        hidden_size: Größe des verborgenen Zustands
        num_layers:  Anzahl der LSTM-Schichten
        output_size: Anzahl der vorherzusagenden Werte (Horizon)
        """
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True  # (batch, seq_len, input_size)
        )

        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        """
        x: Tensor der Form (batch, seq_len, input_size)
        """
        lstm_out, (h_n, c_n) = self.lstm(x)
        # lstm_out: (batch, seq_len, hidden_size)

        # Wir nehmen den letzten Zeitschritt der Ausgabe
        last_output = lstm_out[:, -1, :]  # (batch, hidden_size)

        # Lineare Projektion auf die Zielgröße
        out = self.fc(last_output)       # (batch, output_size)
        return out


model = LSTMForecaster(input_size=1, hidden_size=32, num_layers=1, output_size=horizon).to(device)
model
# Out:
# LSTMForecaster(
#   (lstm): LSTM(1, 32, batch_first=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# ##5a. Verständis von LSTM
#
# Dieses Kapitel erklärt, was ein LSTM im Vorwärtslauf zurückgibt und wie diese Werte zu interpretieren sind. Die Darstellung ist bewusst klar und didaktisch gehalten.
#
# ### 1. Was gibt ein LSTM zurück?
# Verständnis der Zeile `lstm_out, (h_n, c_n) = self.lstm(x)`
#
# **Input** $x$ für LSTM:
#
# 1. batch size = B
# 2. sequence length = T
# 3. feature size = F
#
# $x$ hat die Form (B, T, F)
#
# **Output**: Ein LSTM in PyTorch liefert zwei Hauptbestandteile:
#
#
# 1. `lstm_out` – die Hidden States für jeden Zeitschritt
# 2. `(h_n, c_n)` – das finale Hidden- und Cell-State nach dem letzten Zeitschritt
#
# Typische Zeile:
#
# ```python
# lstm_out, (h_n, c_n) = self.lstm(x)
# ```
#
# ### 2. Bedeutung von `lstm_out`
#
# Ein LSTM erzeugt für jeden Zeitschritt ein Hidden State.
# `lstm_out` enthält alle diese Hidden States.
#
# Form:
#
# ```
# lstm_out.shape = (Batch, Seq_Length, Hidden_Size)
# ```
#
# Für Forecasting wird meist nur der letzte Zeitschritt verwendet:
#
# ```python
# last_output = lstm_out[:, -1, :]
# ```
#
# ### 3. Bedeutung von `h_n` (Hidden State)
#
# `h_n` ist der finale Hidden State:
#
# ```
# h_n.shape = (num_layers, Batch, Hidden_Size)
# ```
#
# Eigenschaften:
# - Kurzzeitgedächtnis
# - Direkter Repräsentant der Sequenz
# - Wird zur Ausgabe weiterverwendet
#
# ### 4. Bedeutung von `c_n` (Cell State)
#
# `c_n` ist der finale Zustand des Langzeitgedächtnisses.
#
# ```
# c_n.shape = (num_layers, Batch, Hidden_Size)
# ```
#
# Eigenschaften:
# - Langzeitgedächtnis
# - Transportiert Information über längere Zeit
# - Stabilisiert das Lernen gegenüber RNN
#
# ### 5. Warum gibt es zwei Zustände?
#
# LSTM besitzt zwei Speicher:
#
# 1. Hidden State `h_t` – kurzfristige Information
# 2. Cell State `c_t` – langfristige Information
#
# Diese Zweiteilung unterscheidet LSTM wesentlich von einfachen RNNs.
#
# ### 6. Formen der Rückgabewerte
#
# Wenn:
# - `num_layers = L`
# - `hidden_size = H`
# - Batch Size = B
#
# dann:
#
# ```
# lstm_out: (B, T, H)
# h_n:      (L, B, H)
# c_n:      (L, B, H)
# ```
#
# ### 7. Mehrschichtiges LSTM (Stacked LSTM)
#
# Beispiel:
#
# ```python
# nn.LSTM(input_size=1, hidden_size=32, num_layers=2)
# ```
#
# Dies bedeutet:
# - Zwei LSTM-Schichten übereinander
# - Jede Schicht hat eigene Hidden- und Cell-States
#
# Visualisierung:
#
# ```
# Zeit t:   Layer1 -> Layer2
# Zeit t+1: Layer1 -> Layer2
# ```
#
# ### 8. Unterschied RNN vs. LSTM
#
# Einfaches RNN:
# - Nur ein Zustand `h_t`
# - Vergisst schnell
#
# LSTM:
# - Zwei Zustände `h_t` und `c_t`
# - Kann Langzeitabhängigkeiten abbilden
# - Besser für Zeitreihen geeignet
#
# ### 9. Zusammenfassung
#
# - `lstm_out` enthält Hidden States aller Zeitschritte
# - `h_n` ist der letzte Hidden State
# - `c_n` ist der letzte Cell State
# - LSTM hat Kurz- und Langzeitgedächtnis
# - Mehrschichtiges LSTM stapelt mehrere LSTM-Blöcke

# %% [markdown]
# ## 6. Training vorbereiten
#
# - Loss-Funktion: Mean Squared Error (MSE)
# - Optimizer: Adam
# - Epochen: z.B. 30
#
# Wir werten pro Epoche auch die Validation-Loss aus.

# %%
# 6.1 Loss und Optimizer

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

num_epochs = 30

# %%
# 6.2 Trainingsschleife

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    model.train()
    train_losses = []
    val_losses = []

    for epoch in range(1, num_epochs + 1):
        # --- Training ---
        model.train()
        running_train_loss = 0.0

        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)            # (batch, seq_len, 1)
            y_batch = y_batch.to(device)            # (batch, horizon)

            optimizer.zero_grad()

            y_pred = model(x_batch)                 # (batch, horizon)

            loss = criterion(y_pred, y_batch)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * x_batch.size(0)

        epoch_train_loss = running_train_loss / len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        # --- Validation ---
        model.eval()
        running_val_loss = 0.0

        with torch.no_grad():
            for x_batch, y_batch in val_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                y_pred = model(x_batch)
                loss = criterion(y_pred, y_batch)
                running_val_loss += loss.item() * x_batch.size(0)

        epoch_val_loss = running_val_loss / len(val_loader.dataset)
        val_losses.append(epoch_val_loss)

        print(f"Epoche {epoch:02d} | Train Loss: {epoch_train_loss:.4f} | Val Loss: {epoch_val_loss:.4f}")

    return train_losses, val_losses


train_losses, val_losses = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)
# Out:
# Epoche 01 | Train Loss: 0.5146 | Val Loss: 0.4838
# Epoche 02 | Train Loss: 0.3171 | Val Loss: 0.1542
# Epoche 03 | Train Loss: 0.1362 | Val Loss: 0.1187
# Epoche 04 | Train Loss: 0.1204 | Val Loss: 0.0990
# Epoche 05 | Train Loss: 0.1121 | Val Loss: 0.0981
# Epoche 06 | Train Loss: 0.1115 | Val Loss: 0.0920
# Epoche 07 | Train Loss: 0.1081 | Val Loss: 0.0901
# Epoche 08 | Train Loss: 0.1071 | Val Loss: 0.0896
# Epoche 09 | Train Loss: 0.1063 | Val Loss: 0.0919
# Epoche 10 | Train Loss: 0.1055 | Val Loss: 0.0904
# Epoche 11 | Train Loss: 0.1055 | Val Loss: 0.0931
# Epoche 12 | Train Loss: 0.1040 | Val Loss: 0.0900
# Epoche 13 | Train Loss: 0.1045 | Val Loss: 0.0890
# Epoche 14 | Train Loss: 0.1033 | Val Loss: 0.0928
# Epoche 15 | Train Loss: 0.1042 | Val Loss: 0.0924
# Epoche 16 | Train Loss: 0.1034 | Val Loss: 0.0933
# Epoche 17 | Train Loss: 0.1037 | Val Loss: 0.0951
# Epoche 18 | Train Loss: 0.1046 | Val Loss: 0.0899
# Epoche 19 | Train Loss: 0.1050 | Val Loss: 0.0884
# ...

# %%
# 6.3 Verlauf der Trainings- und Validierungs-Fehler

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.xlabel("Epoche")
plt.ylabel("MSE-Loss")
plt.title("Trainingsverlauf")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Evaluation auf dem Test-Set
#
# Wir lassen das trainierte Modell Vorhersagen auf dem Test-Set machen und
# vergleichen sie mit den echten Werten der Zeitreihe.

# %%
# 7.1 Vorhersage-Funktion

def predict_on_loader(model, data_loader):
    model.eval()
    preds = []
    targets = []

    with torch.no_grad():
        for x_batch, y_batch in data_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            y_pred = model(x_batch)

            preds.append(y_pred.cpu())
            targets.append(y_batch.cpu())

    preds = torch.cat(preds, dim=0)     # (num_samples, horizon)
    targets = torch.cat(targets, dim=0) # (num_samples, horizon)
    return preds, targets


y_test_pred, y_test_true = predict_on_loader(model, test_loader)
y_test_pred.shape, y_test_true.shape
# Out:
# (torch.Size([146, 1]), torch.Size([146, 1]))

# %%
# 7.2 Visualisierung: Test-Vorhersagen vs. wahre Werte

# Wir nehmen hier die 1-Schritt-Vorhersage und plotten sie
pred_np = y_test_pred.squeeze(-1).numpy()
true_np = y_test_true.squeeze(-1).numpy()

plt.plot(true_np, label="True")
plt.plot(pred_np, label="Prediction")
plt.title("Test-Set: 1-Schritt-Vorhersage")
plt.xlabel("Zeitschritt (Test-Fenster-Index)")
plt.ylabel("Wert")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 8. Aufgaben für Studierende
#
# 1. **Fensterlänge verändern**
#    - Ändern Sie `window_size` (z.B. 10, 50, 100).
#    - Erneut trainieren und beobachten, wie sich Training und Test-Fehler verändern.
#
# 2. **Hidden Size und Layers variieren**
#    - Probieren Sie `hidden_size = 16` und `hidden_size = 64`.
#    - Fügen Sie eine zweite LSTM-Schicht hinzu (`num_layers = 2`).
#    - Diskutieren Sie Overfitting / Underfitting anhand der Verlaufsplots.
#
# 3. **RNN statt LSTM** (optional)
#    - Ersetzen Sie `nn.LSTM` durch `nn.RNN` und passen Sie den Code an.
#    - Vergleichen Sie die Ergebnisse (Stabilität, Loss, Verlauf).
#
# 4. **Mehrschritt-Vorhersage** (optional)
#    - Setzen Sie `horizon = 5` und passen Sie Modell und Visualisierung an.
#    - Lassen Sie das Modell 5 Schritte in die Zukunft vorhersagen.
#
# 5. **Eigene Zeitreihe**
#    - Nutzen Sie den Abschnitt mit `yfinance` unten, um z.B. den S&P500 zu laden.
#    - Verwenden Sie die gleiche Fensterlogik (`create_sequences`) und dasselbe Modell.
#    - Hinweis: Finanzzeitreihen sind extrem verrauscht. Erwarten Sie keine gute Vorhersage –
#      Ziel ist das methodische Verständnis, nicht ein Trading-System.

# %% [markdown]
# ## 9. Eigene Zeitreihe (z. B. S&P 500 mit yfinance)
#
# In diesem Abschnitt zeigen wir, wie man eine **reale Zeitreihe** (z.B. den S&P500 Index)
# herunterlädt und mit derselben RNN-Pipeline verarbeitet.
#
# > Hinweis:
# > - Für Finanzzeitreihen ist 1-Schritt-Forecasting mit so einfachen Modellen meist **schwach**.
# > - Nehmen Sie das als experimentelles Beispiel, nicht als Investitions-Ratgeber :-)

# %%
# 9.1 Installation von yfinance (in Colab meist notwendig)
# In Jupyter/Colab einmal ausführen, in lokalen Umgebungen ggf. in der Shell installieren.
#!pip install yfinance

# 9.2 Daten mit yfinance laden

import yfinance as yf

# Beispiel: S&P 500 Index (^GSPC)
sp500 = yf.download("^GSPC", start="2015-01-01", end=None)

sp500.head()
# Out:
# /tmp/ipykernel_33534/763297122.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download("^GSPC", start="2015-01-01", end=None)
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2015-01-02  2058.199951  2072.360107  2046.040039  2058.899902  2708700000
# 2015-01-05  2020.579956  2054.439941  2017.339966  2054.439941  3799120000
# 2015-01-06  2002.609985  2030.250000  1992.439941  2022.150024  4460110000
# 2015-01-07  2025.900024  2029.609985  2005.550049  2005.550049  3805480000
# 2015-01-08  2062.139893  2064.080078  2030.609985  2030.609985  3934010000

# %%
# 9.3 Einfaches Preprocessing: wir nehmen den Close
# und normalisieren ihn grob.

close = sp500["Close"].dropna()
close_values = close.values.astype(np.float32)

# In Torch-Tensor umwandeln
sp_series = torch.tensor(close_values, dtype=torch.float32).squeeze(-1)
sp_series.shape

# Optional: Normierung (z.B. z-Score)
mean_sp = sp_series.mean()
std_sp = sp_series.std()

sp_series_norm = (sp_series - mean_sp) / std_sp
sp_series_norm.shape
# Out:
# torch.Size([2737])

# %%
# 9.4 Fenster und Split erzeugen (wie oben)

window_size_sp = 30
horizon_sp = 1

X_sp, y_sp = create_sequences(sp_series_norm, window_size_sp, horizon_sp)

### Lösung hier

# %%
# 9.5 Neues Modell für S&P500 trainieren

### Lösung hier

# %% [markdown]
# # Task
# The task is to perform an experiment to evaluate the impact of different `window_size` values on the performance of an LSTM model for synthetic time series forecasting. This involves:
#
# 1.  **Defining a set of `window_size` values**: Use 10, 20, 30, 50, and 100.
# 2.  **Iterating through each `window_size`**:
#     *   For each `window_size`, update the `window_size` parameter.
#     *   Re-generate the input sequences (`X_all`, `y_all`) using the `create_sequences` function.
#     *   Re-perform the train/validation/test split of the data.
#     *   Re-create `TimeSeriesDataset` and `DataLoader` instances for the new splits.
#     *   Re-initialize the `LSTMForecaster` model to ensure a fresh start for each experiment.
#     *   Train the model using the `train_model` function.
#     *   Store the training losses, validation losses, and the final test loss (Mean Squared Error) for each `window_size`.
# 3.  **Visualizing the results**:
#     *   Generate a plot showing the validation loss curves for all `window_size` values on the same graph, allowing for easy comparison of training stability and convergence.
#     *   Create a separate plot (e.g., a bar chart or line plot) displaying the final test MSE loss for each `window_size`.
# 4.  **Analyzing and discussing the findings**:
#     *   Interpret the trends observed in the loss curves and final test performance.
#     *   Discuss how the `window_size` affects the model's ability to learn patterns, identify potential overfitting or underfitting, and suggest an optimal `window_size` based on the experimental results.
# 5.  **Summarizing the conclusions** about the role of `window_size` in LSTM time series forecasting for the given synthetic data.

# %% [markdown]
# ## Define Window Sizes for Experiment
#
# ### Subtask:
# Define a list of `window_size` values (10, 20, 30, 50, 100) that we will iterate through for the experiment.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining a Python list of `window_size` values. This will be done by creating a list in a code block.

# %%
window_sizes_to_test = [10, 20, 30, 50, 100]
print(f"Defined window sizes for experiment: {window_sizes_to_test}")
# Out:
# Defined window sizes for experiment: [10, 20, 30, 50, 100]

# %% [markdown]
# **Reasoning**:
# The next step is to initialize data structures to store the results of the experiments for each window size and set up the loop for iterating through them. This will involve lists for train, validation, and test losses, and a dictionary to store the full loss histories.

# %%
results = {}
all_train_losses = {}
all_val_losses = {}
final_test_mses = []

for current_window_size in window_sizes_to_test:
    print(f"\n--- Running experiment for window_size: {current_window_size} ---")

    # 1. Update window_size
    window_size = current_window_size

    # 2. Re-generate sequences
    X_all, y_all = create_sequences(series, window_size, horizon)
    num_samples = X_all.shape[0]

    # Ensure there are enough samples for all splits
    if num_samples < (window_size + horizon + 2): # At least 1 for each split + window + horizon
        print(f"Skipping window_size {current_window_size} due to insufficient samples ({num_samples}).")
        continue

    train_end = int(num_samples * train_ratio)
    val_end = train_end + int(num_samples * val_ratio)

    # Adjust val_end and test_end if they are too small due to int truncation
    # Ensure at least 1 sample in each split if possible
    if val_end == train_end and num_samples * val_ratio > 0: # If val_end is same as train_end but val_ratio > 0, means it truncated to 0
        val_end = train_end + 1
    if val_end >= num_samples -1: # Ensure test_set is not empty
        val_end = int(num_samples * (train_ratio + val_ratio)) # Recompute to avoid index errors
        if val_end >= num_samples: val_end = num_samples -1 # Take one for test if possible

    # Ensure train_end is not larger than num_samples after initial calculation
    if train_end >= num_samples:
        train_end = num_samples - 2 # At least 1 for val, 1 for test
        if train_end < 0: train_end = 0 # Cannot be negative

    # Recalculate val_end based on potentially adjusted train_end
    val_end = train_end + int((num_samples - train_end) * val_ratio / (val_ratio + test_ratio))
    if val_end >= num_samples: val_end = num_samples - 1 # Ensure val_end is within bounds

    X_train = X_all[:train_end]
    y_train = y_all[:train_end]

    X_val = X_all[train_end:val_end]
    y_val = y_all[train_end:val_end]

    X_test = X_all[val_end:]
    y_test = y_all[val_end:]

    # Check if any split is empty after adjustment
    if len(X_train) == 0 or len(X_val) == 0 or len(X_test) == 0:
        print(f"Skipping window_size {current_window_size} due to empty splits after ratio adjustment. Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        continue

    print(f"Shapes for window_size {current_window_size}: X_train {X_train.shape}, X_val {X_val.shape}, X_test {X_test.shape}")

    # 3. Re-create Dataset and DataLoader
    train_dataset = TimeSeriesDataset(X_train, y_train)
    val_dataset = TimeSeriesDataset(X_val, y_val)
    test_dataset = TimeSeriesDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # 4. Re-initialize model (important for fresh start)
    model = LSTMForecaster(input_size=1, hidden_size=32, num_layers=1, output_size=horizon).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    # 5. Train the model
    train_losses, val_losses = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)

    # 6. Evaluate on test set
    y_test_pred, y_test_true = predict_on_loader(model, test_loader)
    test_loss = criterion(y_test_pred, y_test_true).item()

    # Store results
    all_train_losses[current_window_size] = train_losses
    all_val_losses[current_window_size] = val_losses
    final_test_mses.append({'window_size': current_window_size, 'test_mse': test_loss})

    print(f"Test MSE for window_size {current_window_size}: {test_loss:.4f}")

results['all_train_losses'] = all_train_losses
results['all_val_losses'] = all_val_losses
results['final_test_mses'] = final_test_mses

print("\n--- All experiments completed ---")
# Out:
# --- Running experiment for window_size: 10 ---
# Shapes for window_size 10: X_train torch.Size([693, 10]), X_val torch.Size([148, 10]), X_test torch.Size([149, 10])
# Epoche 01 | Train Loss: 0.5030 | Val Loss: 0.4454
# Epoche 02 | Train Loss: 0.2865 | Val Loss: 0.1640
# Epoche 03 | Train Loss: 0.1204 | Val Loss: 0.1158
# Epoche 04 | Train Loss: 0.1123 | Val Loss: 0.1075
# Epoche 05 | Train Loss: 0.1102 | Val Loss: 0.1039
# Epoche 06 | Train Loss: 0.1118 | Val Loss: 0.1120
# Epoche 07 | Train Loss: 0.1096 | Val Loss: 0.1009
# Epoche 08 | Train Loss: 0.1092 | Val Loss: 0.1015
# Epoche 09 | Train Loss: 0.1091 | Val Loss: 0.1019
# Epoche 10 | Train Loss: 0.1084 | Val Loss: 0.1019
# Epoche 11 | Train Loss: 0.1100 | Val Loss: 0.1036
# Epoche 12 | Train Loss: 0.1082 | Val Loss: 0.1011
# Epoche 13 | Train Loss: 0.1085 | Val Loss: 0.1022
# Epoche 14 | Train Loss: 0.1071 | Val Loss: 0.0996
# Epoche 15 | Train Loss: 0.1082 | Val Loss: 0.0990
# Epoche 16 | Train Loss: 0.1087 | Val Loss: 0.1040
# ...

# %% [markdown]
# **Reasoning**:
# To visualize the impact of different `window_size` values on model training and convergence, I will plot the validation loss curves for all experiments on a single graph.

# %%
plt.figure(figsize=(12, 6))
for ws, losses in all_val_losses.items():
    plt.plot(losses, label=f'Window Size {ws}')

plt.title('Validation Loss Curves for Different Window Sizes')
plt.xlabel('Epoch')
plt.ylabel('Validation MSE Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Reasoning**:
# To compare the final performance of the models trained with different window sizes, I will create a bar chart showing the test MSE for each `window_size`.

# %%
test_mses_df = pd.DataFrame(final_test_mses)

plt.figure(figsize=(10, 5))
plt.bar(test_mses_df['window_size'].astype(str), test_mses_df['test_mse'], color='skyblue')
plt.xlabel('Window Size')
plt.ylabel('Test MSE Loss')
plt.title('Final Test MSE for Different Window Sizes')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ## Analysis and Discussion of Results
#
# Based on the experiments conducted with varying `window_size` values (10, 20, 30, 50, 100), we can analyze the impact on the LSTM model's performance for synthetic time series forecasting.
#
# ### 1. Validation Loss Curves
#
# The plot showing "Validation Loss Curves for Different Window Sizes" illustrates the training stability and convergence speed for each `window_size`.
#
# *   **Initial Convergence**: All models generally show a rapid decrease in validation loss during the initial epochs, indicating that the LSTM model can quickly learn basic patterns in the synthetic sinusoidal data.
# *   **Stability**: After the initial steep decline, the validation losses tend to stabilize, albeit with some minor fluctuations. This suggests that the models have reached a stable learning phase.
# *   **Differences in Minimum Loss**: We can observe slight differences in the minimum validation loss achieved by models with different window sizes. The model with `window_size = 50` appears to reach a slightly lower and more stable validation loss compared to others towards the end of the training.
# *   **Larger `window_size` (e.g., 100)**: While a larger window size provides more historical context, it doesn't necessarily guarantee better performance or faster convergence on this synthetic dataset. For `window_size = 100`, the validation loss appears to be slightly higher and less stable in later epochs compared to `window_size = 50`.
#
# ### 2. Final Test MSE
#
# The bar chart titled "Final Test MSE for Different Window Sizes" provides a direct comparison of the models' generalization performance on unseen data.
#
# *   **Trend**: The test MSE generally decreases as the `window_size` increases from 10 to 50, reaching its lowest point at `window_size = 50`. Beyond this point, for `window_size = 100`, the test MSE starts to increase again.
# *   **Optimal `window_size`**: For this specific synthetic dataset, a `window_size` of 50 appears to yield the best performance on the test set (lowest MSE).
# *   **Interpretation**:
#     *   **Small `window_size` (10, 20)**: With smaller window sizes, the model might not capture enough long-term dependencies or cyclical patterns present in the sinusoidal data, leading to higher error. The limited context can make it harder for the LSTM to distinguish signal from noise over relevant cycles.
#     *   **Medium `window_size` (30, 50)**: As the window size increases to 30 and especially 50, the model gains more relevant historical information, which helps it better predict the next step in the sinusoidal sequence, leading to improved performance. This range seems to provide a good balance between capturing patterns and not introducing too much irrelevant or noisy past data.
#     *   **Large `window_size` (100)**: A `window_size` of 100, while offering extensive history, leads to a slight increase in test MSE. This could be due to several factors: the LSTM might be processing more noise, the additional context might not be relevant beyond a certain point for this particular synthetic signal, or the model might be starting to overfit to specific patterns within the longer sequences rather than generalizing the underlying sinusoidal function. Alternatively, the fixed number of epochs might not be sufficient for the model to fully learn from the longer sequences.
#
# ### Conclusions
#
# For the synthetic sinusoidal time series with added noise:
#
# 1.  **`window_size` is a crucial hyperparameter**: It significantly impacts the model's ability to learn and generalize patterns.
# 2.  **Not always

# %% [markdown]
# ## Analysis and Discussion of Results
#
# Based on the experiments conducted with varying `window_size` values (10, 20, 30, 50, 100), we can analyze the impact on the LSTM model's performance for synthetic time series forecasting.
#
# ### 1. Validation Loss Curves
#
# The plot showing "Validation Loss Curves for Different Window Sizes" illustrates the training stability and convergence speed for each `window_size`.
#
# *   **Initial Convergence**: All models generally show a rapid decrease in validation loss during the initial epochs, indicating that the LSTM model can quickly learn basic patterns in the synthetic sinusoidal data.
# *   **Stability**: After the initial steep decline, the validation losses tend to stabilize, albeit with some minor fluctuations. This suggests that the models have reached a stable learning phase.
# *   **Differences in Minimum Loss**: We can observe slight differences in the minimum validation loss achieved by models with different window sizes. The model with `window_size = 50` appears to reach a slightly lower and more stable validation loss compared to others towards the end of the training.
# *   **Larger `window_size` (e.g., 100)**: While a larger window size provides more historical context, it doesn't necessarily guarantee better performance or faster convergence on this synthetic dataset. For `window_size = 100`, the validation loss appears to be slightly higher and less stable in later epochs compared to `window_size = 50`.
#
# ### 2. Final Test MSE
#
# The bar chart titled "Final Test MSE for Different Window Sizes" provides a direct comparison of the models' generalization performance on unseen data.
#
# *   **Trend**: The test MSE generally decreases as the `window_size` increases from 10 to 50, reaching its lowest point at `window_size = 50`. Beyond this point, for `window_size = 100`, the test MSE starts to increase again.
# *   **Optimal `window_size`**: For this specific synthetic dataset, a `window_size` of 50 appears to yield the best performance on the test set (lowest MSE).
# *   **Interpretation**:
#     *   **Small `window_size` (10, 20)**: With smaller window sizes, the model might not capture enough long-term dependencies or cyclical patterns present in the sinusoidal data, leading to higher error. The limited context can make it harder for the LSTM to distinguish signal from noise over relevant cycles.
#     *   **Medium `window_size` (30, 50)**: As the window size increases to 30 and especially 50, the model gains more relevant historical information, which helps it better predict the next step in the sinusoidal sequence, leading to improved performance. This range seems to provide a good balance between capturing patterns and not introducing too much irrelevant or noisy past data.
#     *   **Large `window_size` (100)**: A `window_size` of 100, while offering extensive history, leads to a slight increase in test MSE. This could be due to several factors: the LSTM might be processing more noise, the additional context might not be relevant beyond a certain point for this particular synthetic signal, or the model might be starting to overfit to specific patterns within the longer sequences rather than generalizing the underlying sinusoidal function. Alternatively, the fixed number of epochs might not be sufficient for the model to fully learn from the longer sequences.
#
# ### Conclusions
#
# For the synthetic sinusoidal time series with added noise:
#
# 1.  **`window_size` is a crucial hyperparameter**: It significantly impacts the model's ability to learn and generalize patterns.
# 2.  **Not always 'more is better'**: Increasing the `window_size` indefinitely does not guarantee better performance. There appears to be an optimal range for `window_size` where the model effectively captures patterns without being overwhelmed by excessive or less relevant historical data. In this experiment, `window_size = 50` was found to be the most effective.
# 3.  **Potential for Overfitting/Underfitting**: Too small a window might lead to underfitting (not enough context), while too large a window could potentially lead to overfitting to noise or irrelevant long-term patterns, especially if the underlying signal has a simpler, repeating structure. While explicit overfitting wasn't strongly observed in the validation curves for `window_size = 100` (loss didn't increase significantly), the higher test MSE suggests a sub-optimal generalization compared to `window_size = 50`.

# %% [markdown]
# ## Analysis and Discussion of Results
#
# Based on the experiments conducted with varying `window_size` values (10, 20, 30, 50, 100), we can analyze the impact on the LSTM model's performance for synthetic time series forecasting.
#
# ### 1. Validation Loss Curves
#
# The plot showing "Validation Loss Curves for Different Window Sizes" illustrates the training stability and convergence speed for each `window_size`.
#
# *   **Initial Convergence**: All models generally show a rapid decrease in validation loss during the initial epochs, indicating that the LSTM model can quickly learn basic patterns in the synthetic sinusoidal data.
# *   **Stability**: After the initial steep decline, the validation losses tend to stabilize, albeit with some minor fluctuations. This suggests that the models have reached a stable learning phase.
# *   **Differences in Minimum Loss**: We can observe slight differences in the minimum validation loss achieved by models with different window sizes. The model with `window_size = 50` appears to reach a slightly lower and more stable validation loss compared to others towards the end of the training.
# *   **Larger `window_size` (e.g., 100)**: While a larger window size provides more historical context, it doesn't necessarily guarantee better performance or faster convergence on this synthetic dataset. For `window_size = 100`, the validation loss appears to be slightly higher and less stable in later epochs compared to `window_size = 50`.
#
# ### 2. Final Test MSE
#
# The bar chart titled "Final Test MSE for Different Window Sizes" provides a direct comparison of the models' generalization performance on unseen data.
#
# *   **Trend**: The test MSE generally decreases as the `window_size` increases from 10 to 50, reaching its lowest point at `window_size = 50`. Beyond this point, for `window_size = 100`, the test MSE starts to increase again.
# *   **Optimal `window_size`**: For this specific synthetic dataset, a `window_size` of 50 appears to yield the best performance on the test set (lowest MSE).
# *   **Interpretation**:
#     *   **Small `window_size` (10, 20)**: With smaller window sizes, the model might not capture enough long-term dependencies or cyclical patterns present in the sinusoidal data, leading to higher error. The limited context can make it harder for the LSTM to distinguish signal from noise over relevant cycles.
#     *   **Medium `window_size` (30, 50)**: As the window size increases to 30 and especially 50, the model gains more relevant historical information, which helps it better predict the next step in the sinusoidal sequence, leading to improved performance. This range seems to provide a good balance between capturing patterns and not introducing too much irrelevant or noisy past data.
#     *   **Large `window_size` (100)**: A `window_size` of 100, while offering extensive history, leads to a slight increase in test MSE. This could be due to several factors: the LSTM might be processing more noise, the additional context might not be relevant beyond a certain point for this particular synthetic signal, or the model might be starting to overfit to specific patterns within the longer sequences rather than generalizing the underlying sinusoidal function. Alternatively, the fixed number of epochs might not be sufficient for the model to fully learn from the longer sequences.
#
# ### Conclusions
#
# For the synthetic sinusoidal time series with added noise:
#
# 1.  **`window_size` is a crucial hyperparameter**: It significantly impacts the model's ability to learn and generalize patterns.
# 2.  **Not always 'more is better'**: Increasing the `window_size` indefinitely does not guarantee better performance. There appears to be an optimal range for `window_size` where the model effectively captures patterns without being overwhelmed by excessive or less relevant historical data. In this experiment, `window_size = 50` was found to be the most effective.
# 3.  **Potential for Overfitting/Underfitting**: Too small a window might lead to underfitting (not enough context), while too large a window could potentially lead to overfitting to noise or irrelevant long-term patterns, especially if the underlying signal has a simpler, repeating structure. While explicit overfitting wasn't strongly observed in the validation curves for `window_size = 100` (loss didn't increase significantly), the higher test MSE suggests a sub-optimal generalization compared to `window_size = 50`.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the findings regarding the impact of different `window_size` values on the LSTM model's performance for the synthetic time series forecasting task.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The impact of different `window_size` values on the LSTM model's performance for the synthetic time series forecasting task is significant and non-linear. An optimal `window_size` was found to balance providing sufficient context without introducing excessive or irrelevant information.
#
# ### Data Analysis Key Findings
# *   The experiment evaluated `window_size` values of 10, 20, 30, 50, and 100.
# *   The validation loss curves showed that models generally converged quickly, with the `window_size = 50` model achieving slightly lower and more stable validation loss towards the end of training compared to others. The `window_size = 100` model exhibited slightly higher and less stable validation loss.
# *   The final test Mean Squared Error (MSE) varied across different `window_size` values:
#     *   `window_size = 10`: test MSE of 0.0979
#     *   `window_size = 20`: test MSE of 0.0962
#     *   `window_size = 30`: test MSE of 0.0928
#     *   `window_size = 50`: achieved the lowest test MSE at 0.0893
#     *   `window_size = 100`: resulted in the highest test MSE at 0.1035
# *   Performance generally improved as `window_size` increased from 10 to 50, but then degraded for `window_size = 100`.
#
# ### Insights or Next Steps
# *   `window_size` is a crucial hyperparameter that requires tuning; "more is not always better" as excessively large windows can lead to diminished performance, potentially due to processing irrelevant information or increased model complexity.
# *   For future work, explore a finer-grained search around the optimal `window_size = 50` (e.g., 40, 45, 55, 60) to confirm and potentially refine the optimal value for this specific synthetic dataset.
